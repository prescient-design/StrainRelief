# %%
from hydra import compose, initialize
from omegaconf import OmegaConf
from rdkit import Chem
from rdkit.Chem import rdDetermineBonds, AllChem
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_3d = True
import pandas as pd

from strain_relief import compute_strain

# %% [markdown]
# ## Running StrainRelief

# %%
# First, lets generate some example poses with 3D coordinates.
smiles = ["CCO", "CCN", "CCC"]
poses = []

for s in smiles:
    mol = Chem.MolFromSmiles(s)
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol)
    mol.SetProp("smiles", s)
    poses.append(mol)

# Note: to run StrainRelief your molecules must either have specified 
# bonds or they must be able to be passed through RDKit's rdDetermineBonds 
# function. This is needed for the conformer enumeration.

# %%
# We now need to initialise a run configuration.
# We use MMFF94s here so that runs will only take a few seconds.
with initialize(version_base="1.1", config_path="../src/strain_relief/hydra_config"):
    cfg = compose(
        config_name="default", 
        overrides=["experiment=mmff94s",]
    )

print(OmegaConf.to_yaml(cfg))
# Out:
# seed: -1
# threshold: 16.1
# numThreads: 0
# io:
#   input:
#     parquet_path: null
#     mol_col_name: null
#     id_col_name: null
#     include_charged: true
#   output:
#     parquet_path: null
#     mol_col_name: ${..input.mol_col_name}
#     id_col_name: ${..input.id_col_name}
# conformers:
#   randomSeed: ${seed}
#   numConfs: 20
#   maxAttempts: 10
#   pruneRmsThresh: 0.1
#   clearConfs: false
#   numThreads: ${numThreads}
# local_min:
#   method: MMFF94s
#   maxIters: 1000
#   MMFFGetMoleculeProperties:
#     mmffVariant: ${..method}
#   MMFFGetMoleculeForceField: {}
#   fmax: 0.5
#   fexit: 250
# global_min:
#   method: MMFF94s
#   maxIters: 1000
#   MMFFGetMoleculeProperties:
#     mmffVariant: ${..method}
#   MMFFGetMoleculeForceField: {}
#   fmax: 0.05
#   fexit: 250
# energy_eval:
#   method: ${global_min.method}

# %% [markdown]
# StrainRelief is run either via the `compute_strain` function or via the command line with the `strain-relief` command. The following three examples demonstrate different ways of running the tool, all giving the same output.

# %%
# EXAMPLE 1

# The minimal requirement to run StrainRelief is a list of RDKit.Mols with 3D poses and a run configration.
# If ids are not given then they will be generated.
results = compute_strain(mols=poses, ids=None, cfg=cfg)
results.head()
# Out:
# CONFIG
# ├── seed
# │   └── -1
# ├── threshold
# │   └── 16.1
# ├── numThreads
# │   └── 0
# ├── io
# │   └── input:
# │         parquet_path: null
# │         mol_col_name: null
# │         id_col_name: null
# │         include_charged: true
# │       output:
# │         parquet_path: null
# │         mol_col_name: ${..input.mol_col_name}
# │         id_col_name: ${..input.id_col_name}
# │
# ├── conformers
# │   └── randomSeed: ${seed}
# │       numConfs: 20
# │       maxAttempts: 10
# │       pruneRmsThresh: 0.1
# │       clearConfs: false
# │       numThreads: ${numThreads}
# │
# ├── local_min
# │   └── method: MMFF94s
# │       maxIters: 1000
# │       MMFFGetMoleculeProperties:
# │         mmffVariant: ${..method}
# │       MMFFGetMoleculeForceField: {}
# │       fmax: 0.5
# │       fexit: 250
# │
# ├── global_min
# │   └── method: MMFF94s
# │       maxIters: 1000
# │       MMFFGetMoleculeProperties:
# │         mmffVariant: ${..method}
# │       MMFFGetMoleculeForceField: {}
# │       fmax: 0.05
# │       fexit: 250
# │
# └── energy_eval
#     └── method: ${global_min.method}
# 2025-12-10 11:17:18.786 | INFO     | strain_relief.io._io:_calculate_charge:156 - Dataset contains 0 charged molecules.
# 2025-12-10 11:17:18.787 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 0, Charge: 0, Spin: 1
# 2025-12-10 11:17:18.787 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 1, Charge: 0, Spin: 1
# 2025-12-10 11:17:18.788 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 2, Charge: 0, Spin: 1
# 2025-12-10 11:17:18.788 | INFO     | strain_relief.compute_strain:compute_strain:78 - Minimising docked conformer...
# 2025-12-10 11:17:18.788 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:43 - Minimising conformers using MMFF94s and removing non-converged conformers...
# 2025-12-10 11:17:18.791 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=2, fmax=0.41854506211229575, E=1.755152390335779
# 2025-12-10 11:17:18.791 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 0
# 2025-12-10 11:17:18.793 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=3, fmax=0.4709352173041563, E=-2.7037614039928886
# 2025-12-10 11:17:18.793 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 1
# 2025-12-10 11:17:18.797 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=3, fmax=0.3991224716437082, E=2.251762826913005
# 2025-12-10 11:17:18.797 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 2
# 2025-12-10 11:17:18.798 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:54 - Predicted energies stored as 'single_point_energy' property on each conformer
# 2025-12-10 11:17:18.798 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:65 - Conformers minimisation took 0.01 seconds.
#
# 2025-12-10 11:17:18.798 | INFO     | strain_relief.conformers._rdkit_generation:generate_conformers:58 - Generating conformers...
# 2025-12-10 11:17:18.800 | DEBUG    | strain_relief.conformers._rdkit_generation:generate_conformers:76 - 1 conformers generated for 0
# 2025-12-10 11:17:18.802 | DEBUG    | strain_relief.conformers._rdkit_generation:generate_conformers:76 - 1 conformers generated for 1
# 2025-12-10 11:17:18.804 | DEBUG    | strain_relief.conformers._rdkit_generation:generate_conformers:76 - 1 conformers generated for 2
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.conformers._rdkit_generation:generate_conformers:81 - 0 molecules with 21 conformers each
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.conformers._rdkit_generation:generate_conformers:84 - Avg. number of conformers is 1.0
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.conformers._rdkit_generation:generate_conformers:85 - Min. number of conformers is 1
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.conformers._rdkit_generation:generate_conformers:90 - Conformer generation took 0.01 seconds.
#
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.compute_strain:compute_strain:85 - Minimising generated conformers...
# 2025-12-10 11:17:18.804 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:43 - Minimising conformers using MMFF94s and removing non-converged conformers...
# 2025-12-10 11:17:18.821 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=38, fmax=0.0491590576904986, E=-1.3282719869669566
# 2025-12-10 11:17:18.821 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 0
# 2025-12-10 11:17:18.839 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=33, fmax=0.04128290286562896, E=-5.628299607310284
# 2025-12-10 11:17:18.839 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 1
# 2025-12-10 11:17:18.864 | DEBUG    | strain_relief.minimisation.utils_bfgs:log:139 - StrainReliefBFGS CONFORMER CONVERGED: Steps=47, fmax=0.046989745647928946, E=-4.8758952073456925
# 2025-12-10 11:17:18.865 | DEBUG    | strain_relief.minimisation.utils_minimisation:remove_non_converged:142 - All conformers converged sucessfully for 2
# 2025-12-10 11:17:18.865 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:54 - Predicted energies stored as 'single_point_energy' property on each conformer
# 2025-12-10 11:17:18.865 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:65 - Conformers minimisation took 0.06 seconds.
#
# 2025-12-10 11:17:18.867 | DEBUG    | strain_relief.io._io:_process_molecule_data:235 - 3.08 kcal/mol ligand strain for molecule 0
# 2025-12-10 11:17:18.867 | DEBUG    | strain_relief.io._io:_process_molecule_data:235 - 2.92 kcal/mol ligand strain for molecule 1
# 2025-12-10 11:17:18.867 | DEBUG    | strain_relief.io._io:_process_molecule_data:235 - 7.13 kcal/mol ligand strain for molecule 2
# 2025-12-10 11:17:18.868 | INFO     | strain_relief.io._io:save_parquet:330 - 3 configurations converged across 3 molecules (avg. 1.00 per molecule)
# 2025-12-10 11:17:18.869 | INFO     | strain_relief.io._io:save_parquet:347 - Output file not provided, data not saved.
# 2025-12-10 11:17:18.870 | INFO     | strain_relief.compute_strain:compute_strain:102 - Ligand strain calculations took 0.09 seconds.
#    id                                          mol_bytes  formal_charge  \
# 0   0  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...              0
# 1   1  b"\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...              0
# 2   2  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...              0
#
#    spin_multiplicity                                      local_min_mol  \
# 0                  1  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
# 1                  1  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
# 2                  1  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
#
#    local_min_e                                     global_min_mol  \
# 0     1.755152  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
# 1    -2.703761  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
# 2     2.251763  b'\xef\xbe\xad\xde\x00\x00\x00\x00\x10\x00\x00...
#
#    global_min_e  ligand_strain  passes_strain_filter  nconfs_converged
# 0     -1.328272       3.083424                  True                 1
# 1     -5.628300       2.924538                  True                 1
# 2     -4.875895       7.127658                  True                 1

# %% [markdown]
# # Lets examine output poses

# %%
results["mol"]  = results["mol_bytes"].apply(Chem.Mol)
results["local_min_mol_actual"]  = results["local_min_mol"].apply(Chem.Mol)
results["global_min_mol_actual"]  = results["global_min_mol"].apply(Chem.Mol)

# %%
# seems ok for input
results["mol"][0]

# %%
# however the local min mols don't seem right
results["local_min_mol_actual"][0]

# %%
# same for global
results["global_min_mol_actual"][0]

# %%
# we can't template them back together
newMol = AllChem.AssignBondOrdersFromTemplate(Chem.RemoveAllHs(results["mol"][0]), results["local_min_mol_actual"][0])
newMol
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # we can't template them back together
# ----> 2 newMol = AllChem.AssignBondOrdersFromTemplate(Chem.RemoveAllHs(results["mol"][0]), results["local_min_mol_actual"][0])
#       3 newMol
#
# File ~/mambaforge/envs/strain_relief/lib/python3.12/site-packages/rdkit/Chem/AllChem.py:477, in AssignBondOrdersFromTemplate(refmol, mol)
#     475       mol2.__sssAtoms = None  # we don't want all bonds highlighted
#     476   else:
# --> 477     raise ValueError("No matching found")
#     478 return mol2
#
# ValueError: No matching found

# %% [markdown]
# # OK lets try a realistic example
#
# Taken from the OpenFE industry benchmark set this is series of ligands posed for free energy calculations
#
# https://github.com/OpenFreeEnergy/IndustryBenchmarks2024/blob/main/industry_benchmarks/input_structures/prepared_structures/jacs_set/tyk2/ligands.sdf
#
# # They are uncharged

# %%
from rdkit.Chem import PandasTools

# %%
df = PandasTools.LoadSDF("./jacs_tyk2_openfe.sdf")

# %%
df["ROMol"][0]

# %%
df["ROMol"][1]

# %%
df["ROMol"][2]

# %%
df["ROMol"][3]

# %%
# now lets do the strain computation

results = compute_strain(mols=df["ROMol"], ids=None, cfg=cfg)
results.head()
# Out:
# CONFIG
# ├── seed
# │   └── -1
# ├── threshold
# │   └── 16.1
# ├── numThreads
# │   └── 0
# ├── io
# │   └── input:
# │         parquet_path: null
# │         mol_col_name: null
# │         id_col_name: null
# │         include_charged: true
# │       output:
# │         parquet_path: null
# │         mol_col_name: ${..input.mol_col_name}
# │         id_col_name: ${..input.id_col_name}
# │
# ├── conformers
# │   └── randomSeed: ${seed}
# │       numConfs: 20
# │       maxAttempts: 10
# │       pruneRmsThresh: 0.1
# │       clearConfs: false
# │       numThreads: ${numThreads}
# │
# ├── local_min
# │   └── method: MMFF94s
# │       maxIters: 1000
# │       MMFFGetMoleculeProperties:
# │         mmffVariant: ${..method}
# │       MMFFGetMoleculeForceField: {}
# │       fmax: 0.5
# │       fexit: 250
# │
# ├── global_min
# │   └── method: MMFF94s
# │       maxIters: 1000
# │       MMFFGetMoleculeProperties:
# │         mmffVariant: ${..method}
# │       MMFFGetMoleculeForceField: {}
# │       fmax: 0.05
# │       fexit: 250
# │
# └── energy_eval
#     └── method: ${global_min.method}
# 2025-12-10 11:27:44.684 | INFO     | strain_relief.io._io:_calculate_charge:156 - Dataset contains 0 charged molecules.
# 2025-12-10 11:27:44.685 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 0, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.685 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 1, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.685 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 2, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.685 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 3, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 4, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 5, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 6, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 7, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 8, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.686 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 9, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.687 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 10, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.687 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 11, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.687 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 12, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.687 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 13, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.687 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 14, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.688 | DEBUG    | strain_relief.io._io:to_mols_dict:100 - Mol ID: 15, Charge: 0, Spin: 1
# 2025-12-10 11:27:44.688 | INFO     | strain_relief.compute_strain:compute_strain:78 - Minimising docked conformer...
# 2025-12-10 11:27:44.689 | INFO     | strain_relief.minimisation._minimisation:minimise_conformers:43 - Minimising conformers using MMFF94s and removing non-converged conformers...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 # now lets do the strain computation
# ----> 3 results = compute_strain(mols=df["ROMol"], ids=None, cfg=cfg)
#       4 results.head()
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/compute_strain.py:79, in compute_strain(cfg, df, mols, ids)
#      77 # Find the local minimum using a looser convergence criteria
#      78 logging.info("Minimising docked conformer...")
# ---> 79 local_minima = minimise_conformers(local_minima, **cfg.local_min)
#      81 # Generate conformers from the docked conformer
#      82 global_minimia = generate_conformers(global_minimia, **cfg.conformers)
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/_minimisation.py:46, in minimise_conformers(mols, method, **kwargs)
#      44 # Select method and run minimisation
#      45 min_method = METHODS_DICT[method]
# ---> 46 energies, mols = min_method(mols=mols, method=method, **kwargs)
#      48 # Store the predicted energies as a property on each conformer
#      49 for mol_id, mol_properties in mols.items():
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/_mmff94.py:51, in MMFF94_min(mols, MMFFGetMoleculeProperties, MMFFGetMoleculeForceField, maxIters, fmax, fexit, method)
#      18 """Minimise all conformers of a Chem.Mol using MMFF94(s).
#      19
#      20 Parameters
#    (...)     45     }
#      46 """
#      47 calculator = RDKitMMFFCalculator(
#      48     MMFFGetMoleculeProperties=MMFFGetMoleculeProperties,
#      49     MMFFGetMoleculeForceField=MMFFGetMoleculeForceField,
#      50 )
# ---> 51 energies, mols = method_min(mols, calculator, maxIters, fmax, fexit)
#      53 return energies, mols
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_minimisation.py:57, in method_min(mols, calculator, maxIters, fmax, fexit, conversion_factor)
#      55 energies: EnergiesDict = {}
#      56 for id, mol_properties in mols.items():
# ---> 57     energies[id], mols[id] = _method_min(
#      58         mol_properties, id, calculator, maxIters, fmax, fexit, conversion_factor
#      59     )
#      60 return energies, mols
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_minimisation.py:106, in _method_min(mol_properties, id, calculator, maxIters, fmax, fexit, conversion_factor)
#     104 for conf_id, conf in conf_id_and_conf:
#     105     conf.info = {"charge": charge, "spin": spin}
# --> 106     new_conf, converged, energy = run_minimisation(conf, calculator, maxIters, fmax, fexit)
#     107     results.append(tuple([converged, energy]))
#     108     conf_id_and_conf_min.append(tuple([conf_id, new_conf]))
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_minimisation.py:189, in run_minimisation(atoms, calculator, maxIters, fmax, fexit)
#     187 atoms.calc = calculator
#     188 dyn = StrainReliefBFGS(atoms)
# --> 189 converged = dyn.run(fmax=fmax, fexit=fexit, steps=maxIters)
#     190 return (
#     191     atoms,
#     192     int(not converged),
#     193     atoms.get_potential_energy(),
#     194 )
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_bfgs.py:42, in StrainReliefBFGS.run(self, steps, fmax, fexit)
#      40 self.n_fmax = 0.0  # maximum force on atom at step n
#      41 self.fexit = fexit
# ---> 42 return self.dynamics_run(steps=steps)
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_bfgs.py:57, in StrainReliefBFGS.dynamics_run(self, steps)
#      44 def dynamics_run(self, steps: int) -> bool:
#      45     """Run dynamics algorithm until convergence or exit.
#      46
#      47     Parameters
#    (...)     55         True if converged.
#      56     """
# ---> 57     for converged in self.dynamics_irun(steps=steps):
#      58         pass
#      59     return converged
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/minimisation/utils_bfgs.py:78, in StrainReliefBFGS.dynamics_irun(self, steps)
#      75 self.max_steps = self.nsteps + steps
#      77 # initial gradient
# ---> 78 self.gradient = self.optimizable.get_gradient()
#      79 self.n_fmax = float(np.linalg.norm(self.gradient.reshape(-1, 3), axis=1).max())
#      81 is_exit = self.exit()
#
# File ~/mambaforge/envs/strain_relief/lib/python3.12/site-packages/ase/optimize/optimize.py:37, in OptimizableAtoms.get_gradient(self)
#      36 def get_gradient(self):
# ---> 37     return self.atoms.get_forces().ravel()
#
# File ~/mambaforge/envs/strain_relief/lib/python3.12/site-packages/ase/atoms.py:886, in Atoms.get_forces(self, apply_constraint, md)
#     884 if self._calc is None:
#     885     raise RuntimeError('Atoms object has no calculator.')
# --> 886 forces = self._calc.get_forces(self)
#     888 if apply_constraint:
#     889     # We need a special md flag here because for MD we want
#     890     # to skip real constraints but include special "constraints"
#     891     # Like Hookean.
#     892     for constraint in self.constraints:
#
# File ~/mambaforge/envs/strain_relief/lib/python3.12/site-packages/ase/calculators/abc.py:32, in GetPropertiesMixin.get_forces(self, atoms)
#      31 def get_forces(self, atoms=None):
# ---> 32     return self.get_property('forces', atoms)
#
# File ~/mambaforge/envs/strain_relief/lib/python3.12/site-packages/ase/calculators/calculator.py:519, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     516     if self.use_cache:
#     517         self.atoms = atoms.copy()
# --> 519     self.calculate(atoms, [name], system_changes)
#     521 if name not in self.results:
#     522     # For some reason the calculator was not able to do what we want,
#     523     # and that is OK.
#     524     raise PropertyNotImplementedError(
#     525         '{} not present in this ' 'calculation'.format(name)
#     526     )
#
# File /store/projects/Kekulai/StrainRelief/src/strain_relief/calculators/_mmff94.py:80, in RDKitMMFFCalculator.calculate(self, atoms, properties, system_changes)
#      78 new_smiles = Chem.MolToSmiles(mol)
#      79 if new_smiles != self.smiles:
# ---> 80     rdDetermineBonds.DetermineBonds(mol, charge=charge)
#      81     self.bond_info = [
#      82         (bond.GetBeginAtomIdx(), bond.GetEndAtomIdx(), bond.GetBondType())
#      83         for bond in mol.GetBonds()
#      84     ]
#      85     self.smiles = new_smiles
#
# ValueError: Final molecular charge (0) does not match input (-2); could not find valid bond ordering
